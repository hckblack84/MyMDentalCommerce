# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df= pd.read_csv("DB.csv", encoding='cp1252', sep=';')

# %%
print(df.head())
# Out:
#   Identificador de URL                               Nombre Categorías  \
# 0                  398       Yeso Piedra Amarillo ELITE 1kg      YESOS
# 1                316-1  Yeso Extraduro Tipo IV Velmix Stone      YESOS
# 2                   40                       Yeso Extraduro      YESOS
# 3                 39-1       Yeso Duro Marca Moldastone M&M      YESOS
# 4                420-3              Cono Papel #15 Gapadent      YESOS
#
#      Precio  Precio promocional  Peso (kg)  Alto (cm)  Ancho (cm)  \
# 0  5,500.00                 NaN        0.0        0.0         0.0
# 1  6,000.00                 NaN        0.0        0.0         0.0
# 2  5,000.00                 NaN        0.0        0.0         0.0
# 3  4,500.00                 NaN        0.0        0.0         0.0
# 4  3,500.00                 NaN        0.0        0.0         0.0
#
#    Profundidad (cm)  Stock  ...  Descripción  Tags Título para SEO  \
# 0               0.0      1  ...          NaN   NaN             NaN
# ...

# %%
id_product = [1 + i for i in range(0, len(df))]

print("INSERT INTO `product` (`id_product`, `code_product`, `cost_price_product`, `critic_stock`, `description_product`, `price_product`, `product_name`, `stock_product`, `department_id_department`) VALUES")
for i in range(0, len(df)):
    print(f"({id_product[i]}, {df['Identificador de URL'].iloc[i]},{df['Precio']},0,Descripcion generica , {df['Categorías'].iloc[i]}, {df['Nombre'].iloc[i]}, {df['Stock'].iloc[i]}),")
# Out:
# INSERT INTO `product` (`id_product`, `code_product`, `cost_price_product`, `critic_stock`, `description_product`, `price_product`, `product_name`, `stock_product`, `department_id_department`) VALUES
# (1, 398,0       5,500.00
# 1       6,000.00
# 2       5,000.00
# 3       4,500.00
# 4       3,500.00
#          ...
# 590     4,000.00
# 591     8,500.00
# 592     3,000.00
# 593     5,500.00
# 594    10,000.00
# Name: Precio, Length: 595, dtype: str:2f,YESOS, Yeso Piedra Amarillo ELITE 1kg, 1),
# (2, 316-1,0       5,500.00
# 1       6,000.00
# 2       5,000.00
# 3       4,500.00
# 4       3,500.00
#          ...
# 590     4,000.00
# 591     8,500.00
# 592     3,000.00
# 593     5,500.00
# 594    10,000.00
# Name: Precio, Length: 595, dtype: str:2f,YESOS, Yeso Extraduro Tipo IV Velmix Stone, 2),
# (3, 40,0       5,500.00
# 1       6,000.00
# 2       5,000.00
# 3       4,500.00
# 4       3,500.00
#          ...
# 590     4,000.00
# 591     8,500.00
# 592     3,000.00
# 593     5,500.00
# ...
